# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import requests 
from config import api_key
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(["bitcoin", "cryptocurrency", "Ethereum", "BTC", "ETH"], cat=0,  geo='', timeframe="today 5-y", gprop='')
# "XRP", "BCH", "ETH",
df = pytrends.interest_over_time()

df.to_csv('/Users/alinas/Desktop/PREWORK_AS/ Cryptocurrency  project /Cryptocurrency_analysis_project/Resources/Google_search.csv')
df.head()
# Out:
#             bitcoin  cryptocurrency  Ethereum  BTC  ETH isPartial
# date
# 2014-04-06        3               0         0    1    0     False
# 2014-04-13        3               0         0    1    0     False
# 2014-04-20        3               0         0    1    0     False
# 2014-04-27        3               0         0    1    0     False
# 2014-05-04        2               0         0    1    0     False

# %%
file = "../Cryptocurrency_analysis_project/Resources/Google_search.csv"
df = pd.read_csv(file)
df.head()
# Out:
#          date  bitcoin  cryptocurrency  Ethereum  BTC  ETH  isPartial
# 0  2014-04-06        3               0         0    1    0      False
# 1  2014-04-13        3               0         0    1    0      False
# 2  2014-04-20        3               0         0    1    0      False
# 3  2014-04-27        3               0         0    1    0      False
# 4  2014-05-04        2               0         0    1    0      False

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df.head()
# Out:
#             bitcoin  cryptocurrency  Ethereum  BTC  ETH  isPartial
# date
# 2014-04-06        3               0         0    1    0      False
# 2014-04-13        3               0         0    1    0      False
# 2014-04-20        3               0         0    1    0      False
# 2014-04-27        3               0         0    1    0      False
# 2014-05-04        2               0         0    1    0      False

# %%
df.loc[df['bitcoin'].idxmax()].index
# Out:
# Index(['bitcoin', 'cryptocurrency', 'Ethereum', 'BTC', 'ETH', 'isPartial'], dtype='object')

# %%
import datetime
import matplotlib.dates as mdates
ax = df.plot(lw=2, colormap='Paired', marker='.', markersize=3, 
         title='Google Search Popularity.')
ax.set_xlabel("Year")
ax.set_ylabel("Popularity")
ax.annotate('17 Dec 2017', xy=("2018", 100), xytext=(15, 15), 
            textcoords='offset points', arrowprops=dict(facecolor='red', shrink=0.05))
ax.grid(linestyle='-', linewidth=0.2)
plt.show()
plt.savefig("../Cryptocurrency_analysis_project/Images/Google_search.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from cryptory import Cryptory

my_cryptory = Cryptory(from_date = "2016-01-01")

# get historical bitcoin prices from coinmarketcap
bitcoin_df = my_cryptory.extract_coinmarketcap("bitcoin")
bitcoin_df.to_csv(r'/Users/alinas/Desktop/PREWORK_AS/ Cryptocurrency  project /Cryptocurrency_analysis_project/Resources/bitcoin_data.csv')

# %%
ethereum_df = my_cryptory.extract_coinmarketcap("Ethereum")
ethereum_df.to_csv(r'/Users/alinas/Desktop/PREWORK_AS/ Cryptocurrency  project /Cryptocurrency_analysis_project/Resources/ethereum_data.csv')

# %%
litecoin_df = my_cryptory.extract_coinmarketcap("Litecoin")
litecoin_df.to_csv(r'/Users/alinas/Desktop/PREWORK_AS/ Cryptocurrency  project /Cryptocurrency_analysis_project/Resources/litecoin_data.csv')

# %%
coins_price_df = my_cryptory.extract_bitinfocharts("btc")
# coins of interest
coins_list = ["btc", "bch", "eth", "ltc", "doge","dash","xmr", "xrp"]
for coin in coins_list[1:]:
    coins_price_df = coins_price_df.merge(my_cryptory.extract_bitinfocharts(coin), on="date", how='inner')
coins_price_df.head()
# print(coins_price_df.columns)
# Out:
#         date  btc_price  bch_price  eth_price  ltc_price  doge_price  \
# 0 2019-04-02     4646.0    194.332    153.069     68.167     0.00259
# 1 2019-04-01     4138.0    168.105    142.086     60.516     0.00229
# 2 2019-03-31     4103.0    167.272    141.459     60.333     0.00208
# 3 2019-03-30     4103.0    167.874    142.857     60.759     0.00208
# 4 2019-03-29     4080.0    169.652    140.268     60.964     0.00208
#
#    dash_price  xmr_price  xrp_price
# 0     120.355     64.410      0.336
# 1     114.566     57.925      0.312
# 2     105.654     54.332      0.310
# 3      97.687     53.643      0.313
# 4      97.376     53.195      0.308

# %%
coins_price_df.to_csv(r'/Users/alinas/Desktop/PREWORK_AS/ Cryptocurrency  project /Cryptocurrency_analysis_project/Resources/coins_price.csv')

# %%
import seaborn as sns
coins_corr_df = coins_price_df.drop('date', axis=1)
corr = coins_corr_df.pct_change().corr(method='pearson')
# Set background color / chart style
sns.set_style(style = 'white')
# Set up  matplotlib figure
fig, ax = plt.subplots(figsize=(9,5)) 
# Add diverging colormap from red to blue
cmap = sns.diverging_palette(250, 10, as_cmap=True) 
sns.heatmap(corr, cmap=cmap,
            xticklabels=[col.replace("_price", "") for col in corr.columns.values],
            yticklabels=[col.replace("_price", "") for col in corr.columns.values],
            annot_kws={"size": 16})
plt.show()
plt.savefig("../Cryptocurrency_analysis_project/Images/corr_crypto.png")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
coins_price_df.columns
coins_price_df['date'] = pd.to_datetime(coins_price_df['date'])
coins_price_df.set_index('date', inplace=True)
coins_price_df.head()
# Out:
#             btc_price  bch_price  eth_price  ltc_price  doge_price  \
# date
# 2019-04-02     4646.0    194.332    153.069     68.167     0.00259
# 2019-04-01     4138.0    168.105    142.086     60.516     0.00229
# 2019-03-31     4103.0    167.272    141.459     60.333     0.00208
# 2019-03-30     4103.0    167.874    142.857     60.759     0.00208
# 2019-03-29     4080.0    169.652    140.268     60.964     0.00208
#
#             dash_price  xmr_price  xrp_price
# date
# 2019-04-02     120.355     64.410      0.336
# 2019-04-01     114.566     57.925      0.312
# 2019-03-31     105.654     54.332      0.310
# 2019-03-30      97.687     53.643      0.313
# 2019-03-29      97.376     53.195      0.308

# %%
coins_price_df = coins_price_df.rename(columns={"btc_price": "Bitcoin(BTC)",
                               "bch_price" : "Bitcoin Cash(BCH)",
                            "eth_price" : "Ethereum(ETH)",
                               "ltc_price" : "Litecoin(LTC)",
                               "doge_price" : "Dogecoin(DOGE)",
                               "dash_price" : "Dash",
                                "xmr_price" : "Monero(XMR)",
                                "xrp_price" : "Ripple(XRP)"})

# %%
# plot the crypto price liniar graph 
coins_price_df
ax = coins_price_df.plot(lw=1, colormap='Paired', marker='.', markersize=2, 
         title='Cryptocurrency Prices Change')
ax.set_xlabel("Year")
ax.set_ylabel("Price($)")
ax.annotate('17 Dec 2017', xy=("2018", 18500), xytext=(10,10), 
            textcoords='offset points', arrowprops=dict(facecolor='red', shrink=0.05),horizontalalignment='left',
            verticalalignment='bottom')
ax.grid(linestyle='-', linewidth=0.2)
plt.show()
plt.savefig("../Cryptocurrency_analysis_project/Images/crypto_prices.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
coins_price_df
# Out:
#             Bitcoin(BTC)  Bitcoin Cash(BCH)  Ethereum(ETH)  Litecoin(LTC)  \
# date
# 2019-04-02        4646.0            194.332        153.069         68.167
# 2019-04-01        4138.0            168.105        142.086         60.516
# 2019-03-31        4103.0            167.272        141.459         60.333
# 2019-03-30        4103.0            167.874        142.857         60.759
# 2019-03-29        4080.0            169.652        140.268         60.964
# 2019-03-28        4032.0            168.410        138.322         60.692
# 2019-03-27        4014.0            166.711        137.827         60.631
# 2019-03-26        3933.0            157.305        133.834         58.498
# 2019-03-25        3974.0            161.939        135.079         59.399
# 2019-03-24        3989.0            163.845        136.269         59.764
# 2019-03-23        4000.0            164.046        136.949         60.333
# 2019-03-22        3999.0            155.116        136.278         58.961
# ...

# %%
#  plt.style.use('seaborn-whitegrid')
df_pct = coins_price_df.pct_change(-1)
df_pct
# sorting in reverse
# Out:
#             Bitcoin(BTC)  Bitcoin Cash(BCH)  Ethereum(ETH)  Litecoin(LTC)  \
# date
# 2019-04-02      0.122765           0.156016       0.077298       0.126429
# 2019-04-01      0.008530           0.004980       0.004432       0.003033
# 2019-03-31      0.000000          -0.003586      -0.009786      -0.007011
# 2019-03-30      0.005637          -0.010480       0.018458      -0.003363
# 2019-03-29      0.011905           0.007375       0.014069       0.004482
# 2019-03-28      0.004484           0.010191       0.003591       0.001006
# 2019-03-27      0.020595           0.059795       0.029835       0.036463
# 2019-03-26     -0.010317          -0.028616      -0.009217      -0.015169
# 2019-03-25     -0.003760          -0.011633      -0.008733      -0.006107
# 2019-03-24     -0.002750          -0.001225      -0.004965      -0.009431
# 2019-03-23      0.000250           0.057570       0.004924       0.023270
# 2019-03-22     -0.006706          -0.006081      -0.009730      -0.008008
# ...

# %%
google_vs_btc = my_cryptory.get_google_trends(kw_list=['bitcoin']).merge(
    my_cryptory.extract_coinmarketcap('bitcoin')[['date','close']], 
    on='date', how='inner')
google_vs_btc.head(5)
# Out:
#         date   bitcoin    close
# 0 2019-03-29  4.637515  4098.37
# 1 2019-03-28  4.512177  4069.11
# 2 2019-03-27  4.637515  4087.07
# 3 2019-03-26  4.261500  3985.08
# 4 2019-03-25  4.136162  3963.07

# %%
google_vs_btc[['bitcoin','close']] = (
        google_vs_btc[['bitcoin', 'close']]- google_vs_btc[['bitcoin', 'close']].min())/(
        google_vs_btc[['bitcoin', 'close']].max()-google_vs_btc[['bitcoin', 'close']].min())

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

ax.plot(google_vs_btc['date'].astype(datetime.datetime),
             google_vs_btc['close'], label='bitcoin', color = "salmon")
ax.plot(google_vs_btc['date'].astype(datetime.datetime),
             google_vs_btc['bitcoin'], label="bitcoin (google search)", color = "steelblue")
ax.set_title('Bitcoin (close price) vs Bitcoin(google search)' )
ax.legend(loc = "best", prop={'size': 15})
ax.set_xlabel("Years")
ax.set_ylabel("Normalisation value")
plt.show()
plt.savefig("../Cryptocurrency_analysis_project/Images/Bitc_vs_search.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
google_vs_ethereum = my_cryptory.get_google_trends(kw_list=['ethereum']).merge(
    my_cryptory.extract_coinmarketcap('ethereum')[['date','close']], 
    on='date', how='inner')
google_vs_ethereum.head()
# Out:
#         date  ethereum   close
# 0 2019-03-29  4.286240  142.50
# 1 2019-03-28  4.822020  139.42
# 2 2019-03-27  3.929053  140.99
# 3 2019-03-26  4.822020  135.46
# 4 2019-03-25  4.107647  135.03

# %%
google_vs_ethereum[['ethereum','close']] = (
        google_vs_ethereum[['ethereum', 'close']]- google_vs_ethereum[['ethereum', 'close']].min())/(
        google_vs_ethereum[['ethereum', 'close']].max()-google_vs_ethereum[['ethereum', 'close']].min())

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.plot(google_vs_ethereum['date'].astype(datetime.datetime),
             google_vs_ethereum['close'], label='ethereum', color = "salmon")
ax.plot(google_vs_btc['date'].astype(datetime.datetime),
             google_vs_btc['bitcoin'], label="ethereum (google search)", color = "steelblue")
ax.set_title('Ethereum (close price) vs Ethereum(google search)' )
ax.legend(loc = "best", prop={'size': 15})
ax.set_xlabel("Years")
ax.set_ylabel("Normalisation value")
plt.show()
plt.savefig("../Cryptocurrency_analysis_project/Images/ethereum_vs_search.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest'
parameters = {
    'symbol' : 'BTC,ETH,XRP,BCH,LTC,EOS',
    'convert': 'USD'}
headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '01d0a6a0-7656-4bcb-9066-4ac179f22282',}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print((json.dumps(data, indent=4, sort_keys=True)))
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print((json.dumps(e, indent=4, sort_keys=True)))
# Out:
# {
#     "data": {
#         "BCH": {
#             "circulating_supply": 17708587.5,
#             "cmc_rank": 4,
#             "date_added": "2017-07-23T00:00:00.000Z",
#             "id": 1831,
#             "last_updated": "2019-04-03T19:36:04.000Z",
#             "max_supply": 21000000,
#             "name": "Bitcoin Cash",
#             "num_market_pairs": 268,
#             "platform": null,
#             "quote": {
#                 "USD": {
#                     "last_updated": "2019-04-03T19:36:04.000Z",
#                     "market_cap": 5934896092.240847,
#                     "percent_change_1h": 3.69165,
#                     "percent_change_24h": 57.6951,
#                     "percent_change_7d": 96.8727,
#                     "price": 335.142263167,
#                     "volume_24h": 4060607841.63115
#                 }
#             },
#             "slug": "bitcoin-cash",
#             "symbol": "BCH",
#             "tags": [
#                 "mineable"
# ...

# %%
crypto_list = []
